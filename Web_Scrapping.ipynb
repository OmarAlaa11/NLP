# %%
import requests #->to get/call the page that i need to scrapping
from bs4 import BeautifulSoup #->to get information for parsing html
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer,PorterStemmer
import re

# %%
# web scraping
def HTML_from_url(url):
    # Fetch HTML content from the URL
    page = requests.get(url)
    src= page.content
    # Parse HTML content
    soup = BeautifulSoup(src, 'lxml')#parser, #parsing  --> to convert byte code into simple code
    return soup

# %%
soup=HTML_from_url(URL)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
# Extract text from HTML
text = soup.get_text()
text
# Out:
# 'Home - BBC NewsHomeNewsSportBusinessInnovationCultureTravelEarthVideoLiveIsrael-Gaza WarWar in UkraineWorldUS & CanadaUKIn PicturesBBC VerifyHomeNewsIsrael-Gaza WarWar in UkraineWorldAfricaAsiaChinaIndiaAustraliaEuropeLatin AmericaMiddle EastUS & CanadaUKEnglandN. IrelandScotlandWalesIn PicturesBBC VerifySportBusinessFuture of BusinessTechnology of BusinessWork CultureInnovationTechnologyScience & HealthArtificial IntelligenceCultureFilm & TVMusicArt & DesignStyleBooksEntertainment NewsTravelDestinationsAfricaAntarcticaAsiaAustralia and PacificCaribbean & BermudaCentral AmericaEuropeMiddle EastNorth AmericaSouth AmericaWorld’s TableCulture & ExperiencesAdventuresThe SpeciaListEarthNatural WondersWeather & ScienceClimate SolutionsSustainable BusinessGreen LivingVideoLiveLive NewsLive Sport\'He will come back’ - Israeli hostage families cling to hope, and demand a dealHow months of trauma after seeing loved ones killed or held captive in Gaza is taking its toll.Middle EastIceland volc
# ...

# %%
stop_words = set(stopwords.words('english'))
def clean_text(sentence):
    # Removing URLS
    sentence = re.sub(r"https?://\S+|www\.\S+"," ",sentence)
    
    # Removing html tags
    sentence = re.sub(r"<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});"," ",sentence)
    
    # Removing the Punctuation
    sentence = re.sub(r"[^\w\s]", " ", sentence)
        
    # Removing words that have numbers 
    sentence = re.sub(r"\w*\d\w*", " ", sentence)
        
    # Removing Digits 
    sentence = re.sub(r"[0-9]+", " ", sentence)
        
    # Cleaning white spaces
    sentence = re.sub(r"\s+", " ", sentence).strip()
        
    sentence = sentence.lower()
    # Check stop words
    tokens = []
    for token in sentence.split():
        if token not in stop_words:
            tokens.append(token)
    stemmer = PorterStemmer()
    stemmed_tokens = [stemmer.stem(word) for word in tokens]
    #lemmatizer = WordNetLemmatizer()
    #lemmatized_tokens = [lemmatizer.lemmatize(word) for word in stemmed_tokens]
    return " ".join(stemmed_tokens)

# %%
clean_text=clean_text(text)
clean_text
# Out:
# 'home bbc newshomenewssportbusinessinnovationculturetravelearthvideoliveisrael gaza warwar ukraineworldu canadaukin picturesbbc verifyhomenewsisrael gaza warwar ukraineworldafricaasiachinaindiaaustraliaeuropelatin americamiddl eastu canadaukenglandn irelandscotlandwalesin picturesbbc verifysportbusinessfutur businesstechnolog businesswork cultureinnovationtechnologysci healthartifici intelligenceculturefilm tvmusicart designstylebooksentertain newstraveldestinationsafricaantarcticaasiaaustralia pacificcaribbean bermudacentr americaeuropemiddl eastnorth americasouth americaworld tablecultur experiencesadventuresth specialistearthnatur wondersweath scienceclim solutionssustain businessgreen livingvideolivel newsliv sport come back isra hostag famili cling hope demand dealhow month trauma see love one kill held captiv gaza take toll middl easticeland volcano lava near grindavik new eruptionan expert say latest flare iceland reykjan peninsula power far europerussia say repel multipl dron
# ...

# %%
tokens = word_tokenize(str(clean_text))
unique_tokens = set(tokens)
unique_tokens
# Out:
# {'abandon',
#  'achiev',
#  'actor',
#  'actress',
#  'actual',
#  'addict',
#  'adult',
#  'advis',
#  'affair',
#  'afraid',
#  'africabilli',
#  'african',
#  'africawhat',
#  'aid',
#  'aim',
#  'airlin',
#  'alabadla',
#  'alexei',
#  'alien',
#  'alight',
#  'aliv',
#  'along',
#  'alreadi',
#  'amass',
#  'america',
#  'americaeuropemiddl',
#  'americamiddl',
#  'americasouth',
#  'americaworld',
#  'amid',
#  'analysi',
#  'analysisidri',
#  'analyst',
#  'announc',
#  'anonym',
#  'anoth',
#  'app',
#  'appeas',
#  'appoint',
#  'approach',
#  'arch',
#  'arctic',
#  'around',
#  'artsiceland',
#  'artsisrael',
#  'artstrudeau',
#  'artswhat',
#  'ask',
#  'attack',
#  'attacksdozen',
#  'attent',
#  'author',
#  'authoris',
#  'await',
#  'awar',
#  'away',
#  'babyam',
#  'back',
#  'badli',
#  'battl',
#  'bayern',
#  'bbc',
#  'bbcadvertis',
#  'bbcprivaci',
#  'beat',
#  'becom',
#  'bermudacentr',
#  'best',
#  'big',
#  'black',
#  'bodi',
#  'boe',
#  'bomb',
# ...

# %%
len(unique_tokens)
# Out:
# 641

# %%
l=[]
unique_tokens_list=list(unique_tokens)
for i in range(len(unique_tokens_list)):
    if len(unique_tokens_list[i])<3:
        l.append(unique_tokens_list[i])
l
# Out:
# ['u', 'us', 'fi', 'pm', 'fa', 'ex', 'tv']
